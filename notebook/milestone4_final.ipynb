# %%
import sys
import os

# 1. Define the root path first
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))

# 2. Add it to the system path
sys.path.append(PROJECT_ROOT)

# 3. NOW you can safely import your app
from app import app

# Optional: verify for debugging
# print(f"show",PROJECT_ROOT)
print(f"Project root added")
# Out:
# Project root added

# %%
state = app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow"
})
state
# Out:
# {'response': 'Dear Bob,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {},
#  'paused': False}

# %%
state = app.invoke({
    "input": "Actually, call him Robert, not Bob.",
    "memory": state.get("memory", {})
})
state
# Out:
# {'response': 'Dear Robert,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}

# %%
app.invoke({
    "input": "Please draft an email to Bob about the meeting tomorrow",
    "memory": state.get("memory", {}
    )
})
# Out:
# {'response': 'Dear Robert,\n\nI hope you are doing well.\nThis is a reminder about our meeting scheduled for tomorrow.\n\nBest regards,\n',
#  'memory': {'name_preference': 'Robert'},
#  'paused': False}

# %%
state = {
    "input": "Email Bob about the project update tomorrow",
    "memory": {
        "to": "bob@example.com",
        "subject": "Project Update"
    }
}

result = app.invoke(state)
result
# Out:
# {'response': 'Dear Bob,\n\nThis is a professional email.\n\nBest regards,\n',
#  'memory': {'to': 'bob@example.com', 'subject': 'Project Update'},
#  'paused': False}
