# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Deepalakshmi\Downloads\sample_emails_with_triage_200.csv")

# %%
DANGEROUS_TOOLS = ["send_email","create_calender_invite"]

# %%
def agent_decide_action(body):
    if "meeting" in body.lower():
        return "create_calender_invite"
    if "reply"in body.lower():
        return "send_email"
    return "read_calender"

# %%
def hitl_checkpoint(action):
    if action in DANGEROUS_TOOLS:
        return "WAIT FOR HUMAN"
    return "SAFE"

# %%
def human_decision():
    return "Approve"

# %%
def execute_tool(action):
    return f"Executed action: {action}"

# %%
def run_agent(body):
    print("Email received:", body)

    action = agent_decide_action(body)
    print("Agent decided action:", action)

    status = hitl_checkpoint(action)
    print("HITL status:" , status)

    if status == "WAIT FOR HUMAN":
        decision = human_decision()
        print("Human decided action:", decision)

        if decision == "Approve":
            return execute_tool(action)
        elif decision == "Deny":  
            return "Action denied by human."
        elif decision == "Edit":
            return "Action edited by human."
    return execute_tool(action)

# %%
email = "Please schedule a meeting with the client "
result = run_agent(email)
result
# Out:
# Email received: Please schedule a meeting with the client
# Agent decided action: create_calender_invite
# HITL status: WAIT FOR HUMAN
# Human decided action: Approve
# 'Executed action: create_calender_invite'
